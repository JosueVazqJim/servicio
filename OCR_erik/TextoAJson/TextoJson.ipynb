# %%
import json
import re
import os
import glob
from limpiador_texto import LimpiezaTexto

class TextoJson:
    """
    Clase para procesar y estructurar texto médico en un formato JSON.

    Esta clase toma un archivo de texto con información médica, la procesa y la estructura
    en un formato JSON que incluye secciones como antecedentes personales, antecedentes familiares,
    estadía  tumoral, inmunohistoquímica tumoral, y tipo de cáncer.
    Basta con usar el metodo convertir_txt_json para convertir un archivo de texto a un archivo JSON.
    Se le pasa la ruta del archivo de texto y la ruta de destino donde se guardará el archivo JSON.

    Attributes:
        limpiador (LimpiezaTexto): Instancia de la clase LimpiezaTexto para procesar el texto.
        informacion (list): Lista de líneas de texto procesadas.
        data (dict): Diccionario que almacena la información estructurada en formato JSON.
        rutaTxt (str): Ruta del archivo de texto de entrada.
        rutaDestino (str): Ruta de la carpeta donde se guardarán los archivos JSON.
    """

    def __init__(self):
        """
        Inicializa la clase TextoJson.
        """
        self.rutaTxt = None
        self.rutaDestino = None
        self.limpiador = LimpiezaTexto()
        self.fases = []
        self.informacion = []
        self.data = {
            "antecedentes_personales": {},
            "antecedentes_familiares": {},
            "estadía_tumoral": {},
            "inmunohistoquímica_tumoral": {},
            "tipo": {},
        }
        self.mama = None

    def __limpiar_texto(self):
        """
        Limpia el texto de entrada utilizando la instancia de LimpiezaTexto.
        """
        self.informacion = self.limpiador.limpiar_archivo(self.rutaTxt)

    def setrutaTxt(self, rutaTxt):
        self.rutaTxt = rutaTxt

    def setrutaDestino(self, rutaDestino):
        self.rutaDestino = rutaDestino

    def __hay_fases(self):
        """
        Verifica si el contenido contiene fases separadas por líneas de asteriscos,
        seguido de texto real en las siguientes líneas.
        
        Retorna:
            bool: True si hay fases detectadas, False en caso contrario.
        """
        asterisco_pattern = re.compile(r'^\*+$')
        
        for i, linea in enumerate(self.informacion):
            linea = linea.strip()
            
            if asterisco_pattern.match(linea):
                # Revisar si después de los asteriscos hay texto real
                if i + 1 < len(self.informacion):
                    siguiente_linea = self.informacion[i + 1].strip()
                    if siguiente_linea:  # Hay contenido después de los asteriscos
                        return True
        return False  # No se detectaron fases reales
    
    def __separar_fases(self):
        """
        Divide el contenido en diferentes fases
        cada vez que encuentra líneas de asteriscos.
        
        Almacena cada fase como un elemento en la lista self.fases.
        """
        self.fases = []
        fase_actual = []
        asterisco_pattern = re.compile(r'^\*+$')
        
        for linea in self.informacion:
            linea = linea.strip()
            
            if asterisco_pattern.match(linea):
                if fase_actual:
                    self.fases.append(fase_actual)
                    fase_actual = []
            else:
                if linea:
                    fase_actual.append(linea)
        
        if fase_actual:
            self.fases.append(fase_actual)

    def __detector_pezones(self):
        """
        Establece el lado de la mama del caso actual.
        Solo considera las mamas afectadas por cáncer, basándose en las secciones de diagnóstico,
        extensión del tumor o biología tumoral. 
        En caso de no detectar ninguna mama afectada, se establece como Non y se continua llenando
        la estructura JSON sin indicar la mama afectada.
        """
        mama_izquierda_flag = False
        mama_derecha_flag = False
        bilateral_flag = False

        # Palabras clave que indican las secciones relevantes
        secciones_relevantes = ["diagnóstico", "extensión del tumor", "biología tumoral", "mama"]

        for linea in self.informacion:
            # Verificar si la línea pertenece a una sección relevante
            if any(linea.startswith(seccion) for seccion in secciones_relevantes):
                if "mama izquierda" in linea:
                    mama_izquierda_flag = True
                if "mama derecha" in linea:
                    mama_derecha_flag = True
                if "bilateral" in linea:
                    bilateral_flag = True

        # Determinar el lado de la mama basado en las banderas
        if (mama_izquierda_flag and mama_derecha_flag) or (bilateral_flag):
            self.mama = "bilateral"
        elif mama_izquierda_flag:
            self.mama = "mama_izquierda"
        elif mama_derecha_flag:
            self.mama = "mama_derecha"  
        else:
            self.mama = None  # Si no se detecta ninguna mama afectada
        
        print(f"Se detectó mama: {self.mama}")



    def __extraer_nombre_txt(self):
        """
        Extrae el nombre del archivo de texto de la ruta de archivo.
        devuelve el nombre del archivo de texto
        """
        return os.path.basename(self.rutaTxt)

    def __extract_units(self, data):
        """
        Extrae unidades de tiempo (años, meses, días, horas) de una cadena de texto.

        Args:
            data (str): Cadena de texto que contiene las unidades de tiempo.

        Returns:
            list: Lista de tuplas con el valor y la unidad de tiempo.
        """
        # Regular expression to match patterns like "años", "meses", "días", "horas"
        unit_pattern = re.compile(
            r'\b(\d+\.?\d*)\s*(año|años|mes|meses|día|días|hora|horas)\b|\b(año|años|mes|meses|día|días|hora|horas)\s*(\d+\.?\d*)\b',
            re.IGNORECASE
        )
        matches = unit_pattern.findall(data)

        units = []
        for match in matches:
            if match[0] and match[1]:  # Caso: "1 año" o "1.5 años"
                value = float(match[0]) if '.' in match[0] else int(match[0])  # Parseo de dígitos
                units.append((value, match[1]))
            elif match[2] and match[3]:  # Caso: "año 1" o "años 1.5"
                value = float(match[3]) if '.' in match[3] else int(match[3])  # Parseo de dígitos
                units.append((value, match[2]))

        return units

    def __extraer_datos_antecedentes_personales(self):
        """
        Extrae y estructura los datos de antecedentes personales del texto procesado.

        Los datos se almacenan en el diccionario `data` bajo la clave "antecedentes_personales".
        """
        # secciones de antecedentes_personales
        antecedentes_personales_secciones = {
            "edad": None,
            "sexo": "femenino",
            "peso": None,
            "talla": None,
            "preferencia": None,
            "índice_tabáquico": {
                "fuma": None,
                "observaciones": None
            },
            "alcohol": None,
            "drogas": None,
            "comorbilidades": None,
            "antecedentes_ginecológicos": {
                "fum": None,
                "menarca": None,
                "trh": None,
                "aco": None,
                "mpf": None,
                "estado_hormonal": None,
                "métodos_anticonceptivos": None,
                "g": None,
                "p": None,
                "c": None,
                "a": None
            }
        }

        #palaras clave para antecedentes_personales que buscaremos en el texto
        antecedentes_personales_keywords = [
           "sexo", "peso", "talla", "preferencia",
            "índice tabáquico", "tabaco", "tabaquismo", "alcohol", "drogas",
            "comorbilidades", "antecedentes ginecológicos", "menarca", "fum", 
            "trh", "mpf", "aco", "estado hormonal", "métodos anticonceptivos"
        ]

        isEdad = False
        isEstadoHormonal = False

        # Agregar una regex para detectar edades en el formato "XX años"
        edad_regex = re.compile(
            r'\b(?:edad:?\s*(\d+)(?:\s*años)?)|'  # Caso 1: "edad: 45" o "edad 45 años"
            r'(?:\b(\d+)\s*años(?:\s*de\s*edad)?)|'  # Caso 2: "45 años" o "45 años de edad"
            r'^(.*?)\s*/\s*(\d+)\s*/\s*(\d+\s*años?)\s*/\s*(.*)$',  # Caso 3: "institución / ID / edad / médico"
            re.IGNORECASE
        )

        g_p_c_a_regex = re.compile(r'\b([g]\d+)\s([p]\d+)\s([c]\d+)\s([a]\d+)\b', re.IGNORECASE)

        for linea in self.informacion:
            # Buscar una edad en el formato específico
            match = edad_regex.match(linea)
            if match:
                edad_valor = linea

                if edad_valor:
                    try:
                        unidades = self.__extract_units(edad_valor)
                        edad_dict = {}
                        for cantidad, unidad in unidades:
                            if unidad == "años":
                                edad_dict["años"] = cantidad
                            elif unidad == "meses":
                                edad_dict["meses"] = cantidad
                            elif unidad == "días":
                                edad_dict["días"] = cantidad
                            elif unidad == "horas":
                                edad_dict["horas"] = cantidad
                        antecedentes_personales_secciones["edad"] = edad_dict
                    except (IndexError, ValueError):
                        antecedentes_personales_secciones["edad"] = {"años": None}

                isEdad = True

            matchGPCA = g_p_c_a_regex.match(linea)
            if matchGPCA:
                antecedentes_personales_secciones["antecedentes_ginecológicos"]['g'] = int(matchGPCA[1][1:])  # Quitar el 'g' y tomar el número
                antecedentes_personales_secciones["antecedentes_ginecológicos"]['p'] = int(matchGPCA[2][1:])  # Quitar el 'p' y tomar el número
                antecedentes_personales_secciones["antecedentes_ginecológicos"]['c'] = int(matchGPCA[3][1:])  # Quitar el 'c' y tomar el número
                antecedentes_personales_secciones["antecedentes_ginecológicos"]['a'] = int(matchGPCA[4][1:])  # Quitar el 'a' y tomar el número

            for keyword in antecedentes_personales_keywords:
                if keyword in linea:

                    # Si la keyword es "tabaquismo" o "tabaco" o "índice tabáquico" y si tiene o no ":" que separan
                    if keyword == "tabaquismo" or keyword == "tabaco" or keyword == "índice tabáquico":
                        # Removemos los ":" si están presentes
                        if ":" in linea:
                            linea = linea.replace(":", "")

                        # Extraemos el estado del tabaquismo y cualquier unidad de tiempo
                        estados = ["negado", "suspendido", "fumador", "negadas"]
                        for estado in estados:
                            if estado in linea:
                                antecedentes_personales_secciones["índice_tabáquico"]["fuma"] = estado
                                # Verificamos si hay algo más en la línea
                                if len(linea.split(estado)[1].strip()) > 0:
                                    notas = linea.split(estado)[1].strip()
                                    observaciones = notas.split(". ")
                                    observaciones_list = []
                                    for observacion in observaciones:
                                        unidades = self.__extract_units(observacion)
                                        if unidades:
                                            exposicion = {"notas": observacion, "tiempo": {}}
                                            for cantidad, unidad in unidades:
                                                if unidad == "años":
                                                    exposicion["tiempo"]["años"] = cantidad
                                                elif unidad == "meses":
                                                    exposicion["tiempo"]["meses"] = cantidad
                                                elif unidad == "días":
                                                    exposicion["tiempo"]["días"] = cantidad
                                                elif unidad == "horas":
                                                    exposicion["tiempo"]["horas"] = cantidad
                                            observaciones_list.append(exposicion)

                                    if observaciones_list:
                                        antecedentes_personales_secciones["índice_tabáquico"]["observaciones"] = observaciones_list
                                    else:
                                        antecedentes_personales_secciones["índice_tabáquico"]["observaciones"] = None
                                break


                    elif keyword in ["fum", "menarca", "trh", "aco", "mpf", "estado hormonal", "métodos anticonceptivos"]:
                        # Patrón para identificar claves ginecológicas en la línea
                        pattern = re.compile(r'\b(fum|menarca|trh|mpf|aco|estado hormonal|métodos anticonceptivos)\b', re.IGNORECASE)
                        pattern_especial = re.match(r"menarca a los (\d+) años\. (\d+) embarazos?, (\d+) partos?", linea, re.IGNORECASE)

                        if pattern_especial:
                            edad_menarca, num_embarazos, num_partos = map(int, pattern_especial.groups())
                            antecedentes_personales_secciones["antecedentes_ginecológicos"]["menarca"] = {"años": edad_menarca}
                            
                        else:
                            # Eliminar guiones y limpiar la línea
                            linea_limpia = re.sub(r'^-\s*', '', linea.strip())
                            matches = pattern.findall(linea)
                            
                            if len(matches) > 1:
                                # Separar por "/", ",", "y"
                                partes = re.split(r'\s*[\/,]\s*|\s+y\s+', linea_limpia)
                                valores = {}
                                
                                for parte in partes:
                                    parte = parte.strip()
                                    for keyword in matches:
                                        if keyword in parte:
                                            valor = None
                                            if ":" in parte:
                                                valor = parte.split(":")[1].strip()
                                            else:
                                                valor = parte.replace(keyword, "").strip()

                                            # Verificar si el valor está vacío y hay más claves
                                            if not valor and len(matches) > 1:
                                                valor = partes[-1].strip()

                                            unidades = self.__extract_units(valor)
                                            if unidades:
                                                valor_dict = {unidad: cantidad for cantidad, unidad in unidades}
                                                if len(valor.split()) > 2:
                                                    valor_dict["contexto"] = valor
                                                valores[keyword.strip().replace(" ", "_")] = valor_dict
                                            else:
                                                valores[keyword.strip().replace(" ", "_")] = valor
                                
                                # Caso especial: múltiples claves comparten el mismo valor
                                if any(separador in linea_limpia for separador in [" y ", "/", ","]):
                                    #imprimimos la linea que cae en este caso
                                    ultima_clave = matches[-1]
                                    valor_comun = linea_limpia.split(ultima_clave)[1].strip() if ":" not in linea_limpia else linea_limpia.split(":")[1].strip()
                                    for keyword in matches:
                                        if keyword not in valores:
                                            valores[keyword.strip().replace(" ", "_")] = valor_comun
                                
                                antecedentes_personales_secciones["antecedentes_ginecológicos"].update(valores)
                            
                            elif 'estado hormonal' in matches:
                                if isEstadoHormonal == False:
                                    isEstadoHormonal = True
                                    valor = None
                                    if ":" in linea_limpia:
                                        valor = linea_limpia.split(":")[1].strip()
                                    else:
                                        valor = linea_limpia.split(matches[0])[1].strip()
                                    
                                    unidades = self.__extract_units(valor)
                                    if unidades:
                                        valor_dict = {unidad: cantidad for cantidad, unidad in unidades}
                                        if len(valor.split()) > 2:
                                            valor_dict["contexto"] = valor
                                        antecedentes_personales_secciones["antecedentes_ginecológicos"][matches[0].strip().replace(" ", "_")] = valor_dict
                                    else:
                                        antecedentes_personales_secciones["antecedentes_ginecológicos"][matches[0].strip().replace(" ", "_")] = valor
                                
                            else:
                                if matches:
                                    keyword = matches[0]
                                    valor = None
                                    
                                    if ":" in linea_limpia:
                                        valor = linea_limpia.split(":")[1].strip()
                                    else:
                                        valor = linea_limpia.split(keyword)[1].strip()

                                    unidades = self.__extract_units(valor)
                                    if unidades:
                                        valor_dict = {unidad: cantidad for cantidad, unidad in unidades}
                                        if len(valor.split()) > 2:
                                            valor_dict["contexto"] = valor
                                        antecedentes_personales_secciones["antecedentes_ginecológicos"][keyword.strip().replace(" ", "_")] = valor_dict
                                    else:
                                        antecedentes_personales_secciones["antecedentes_ginecológicos"][keyword.strip().replace(" ", "_")] = valor                  

                    elif keyword == "comorbilidades":
                        comorbilidades = linea
                        comorbilidades = comorbilidades.replace("comorbilidades:", "").strip()
                        
                        # Verificar si está negado
                        if "negad" in comorbilidades:
                            antecedentes_personales_secciones["comorbilidades"] = "negadas"
                            continue
                        
                        # Dividir la cadena en comorbilidades individuales
                        comorbilidades_list = re.split(r'\d+\.\s|\/|\|', comorbilidades)

                        # Eliminar posibles cadenas vacías resultantes de la división
                        comorbilidades_list = [comorbilidad for comorbilidad in comorbilidades_list if comorbilidad]

                        comorbilidades_dict = {}

                        # Inicializar el campo "sin_fecha"
                        comorbilidades_dict["sin_fecha"] = []

                        for comorbilidad in comorbilidades_list:
                            comorbilidad = comorbilidad.strip()
                            # Extraer el año, que puede estar en formato (YYYY) o (MM.YYYY)
                            match = re.search(r'\((\d{4}|\d{2}\.\d{4})\)', comorbilidad)
                            if match:
                                year = match.group(1)
                                # Separar nombre y descripción
                                parts = comorbilidad.split(f"({year})")
                                nombre = parts[0].strip()
                                descripcion = parts[1].strip() if len(parts) > 1 else ""

                                # Si la descripción es solo un punto, lo agregamos al nombre
                                if descripcion == ".":
                                    descripcion = None  # Dejamos la descripción vacía
                                    nombre = nombre.rstrip('.')  # Quitamos el punto del nombre

                                if year not in comorbilidades_dict:
                                    comorbilidades_dict[year] = []

                                comorbilidades_dict[year].append({
                                    "nombre": nombre.strip(),
                                    "descripción": descripcion.lstrip(': ') if descripcion else None
                                })
                            else:
                                # Si no hay fecha, agregar a "sin_fecha"
                                comorbilidades_dict["sin_fecha"].append({
                                    "nombre": comorbilidad.strip(),
                                    "descripción": None  # No hay descripción si no hay fecha
                                })
                        
                        #si no hay comorbilidades sin fecha, eliminar el campo
                        if not comorbilidades_dict["sin_fecha"]:
                            del comorbilidades_dict["sin_fecha"]
                        antecedentes_personales_secciones["comorbilidades"] = comorbilidades_dict

                    else:
                        if re.match(r'^\d+\.|\(\d{4}\)', linea):  # Evitar claves en listas numeradas o con fechas
                            continue
                        elif ":" in linea:
                            antecedentes_personales_secciones[keyword.replace(" ", "_")] = linea.split(":")[1].strip()
                        else:
                            antecedentes_personales_secciones[keyword.replace(" ", "_")] = linea.split(keyword)[1].strip()

        self.data["antecedentes_personales"] = antecedentes_personales_secciones
        #self.imprimir_json()

    def __extraer_datos_antecedentes_familiares(self):
        """
        Extrae y estructura los datos de antecedentes familiares del texto procesado.

        Los datos se almacenan en el diccionario `data` bajo la clave "antecedentes_familiares".
        """
        antecedentes_familiares_secciones = {
            "ascendencia": None,
            "lateralidad": None,
            "descendencia": None,
        }

        for linea in self.informacion:
            linea = linea.strip()

            # Verificar si está negado
            if "ahf" in linea and "negado" in linea:
                self.data["antecedentes_familiares"] = {
                    "ascendencia": "negado",
                    "lateralidad": "negado",
                    "descendencia": "negado"
                }
                return

            if "ahf" in linea:
                # Remover la parte inicial "AHF oncológicos:" si está presente
                if ":" in linea:
                    linea = linea.split(":", 1)[1].strip()

                # Inicializar listas para cada categoría
                ascendencia = []
                lateralidad = []
                descendencia = []

                # Separar la línea en partes basadas en "/", "-", ",", o ";"
                partes = re.split(r'[\/\-;,.]', linea)

                for parte in partes:
                    parte = parte.strip()
                    # Verificar si la parte contiene alguna relación familiar
                    if any(rel in parte for rel in ["primo", "tío", "prima", "tía", "hermano", "hermana"]):
                        lateralidad.append(parte)
                    elif any(rel in parte for rel in ["padre", "madre", "abuelo", "abuela", "papá", "mamá"]):
                        ascendencia.append(parte)
                    elif any(rel in parte for rel in ["hija", "hijo", "nieto", "nieta"]):
                        descendencia.append(parte)

                # Asignar las listas a las secciones correspondientes
                antecedentes_familiares_secciones["ascendencia"] = ascendencia if ascendencia else None
                antecedentes_familiares_secciones["lateralidad"] = lateralidad if lateralidad else None
                antecedentes_familiares_secciones["descendencia"] = descendencia if descendencia else None

        self.data["antecedentes_familiares"] = antecedentes_familiares_secciones
        # self.imprimir_json()

    def __extraer_datos_inmunohistoquímica_tumoral(self):
        """
        Extrae y estructura los datos de inmunohistoquímica tumoral del texto procesado.
        Primero busca en 'biología tumoral' y solo si no encuentra datos, busca en 'diagnóstico'.
        Mantiene la estructura original de dos diccionarios separados.
        """
        # Estructura de datos para inmunohistoquímica tumoral
        inmunohistoquimica_tumoral_secciones = {
            "mama_izquierda": {
                "re": None, "rp": None, "her2": None, "ki67": None, "gh": None
            },
            "mama_derecha": {
                "re": None, "rp": None, "her2": None, "ki67": None, "gh": None
            }
        }

        # Patrones de búsqueda mejorados (incluyendo el patrón para HER2 con paréntesis)
        patrones = {
            "re": re.compile(r"re\s*[:]?\s*(\d+%|\+|\-|positivo|negativo)", re.IGNORECASE),
            "rp": re.compile(r"rp\s*[:]?\s*(\d+%|\+|\-|positivo|negativo)", re.IGNORECASE),
            "her2": re.compile(r"her\s*2\s*[:]?\s*((?:\+{1,3})|\d+\+?\s*\(.*?\)|\d+\+?|\-|\+|negativo|positivo)", re.IGNORECASE),
            "ki67": re.compile(r"ki67\s*[:]?\s*(\d+%|\w+)", re.IGNORECASE),
            "gh": re.compile(r"gh\s*[:]?\s*(\d+)", re.IGNORECASE)
        }

        # Variables para controlar si encontramos datos en biología tumoral
        encontrado_en_biologia = False

        # Primera pasada: buscar solo en biología tumoral
        for linea in self.informacion:            
            # Verificar si estamos en biología tumoral
            if "biología tumoral" in linea:
                encontrado_en_biologia = True
                # Extraer datos para cada marcador
                for marcador, patron in patrones.items():
                    match = patron.search(linea)
                    if match:
                        valor = match.group(1).strip()
                        
                        # Asignar el valor según la mama detectada
                        if self.mama == "bilateral":
                            # Procesamiento especial para casos bilaterales
                            secciones = re.split(r"mama (izquierda|derecha)", linea, flags=re.IGNORECASE)
                            for i, seccion in enumerate(secciones):
                                if seccion == "izquierda":
                                    match_izq = patron.search(secciones[i+1])
                                    if match_izq:
                                        val = match_izq.group(1).strip()
                                        inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] = val
                                elif seccion == "derecha":
                                    match_der = patron.search(secciones[i+1])
                                    if match_der:
                                        val = match_der.group(1).strip()
                                        inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] = val
                        elif self.mama == "mama_izquierda":
                            inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] = valor
                        elif self.mama == "mama_derecha":
                            inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] = valor

        # Segunda pasada: buscar en diagnóstico solo si no encontramos en biología tumoral
        if not encontrado_en_biologia or not any(
            val is not None 
            for dic in [inmunohistoquimica_tumoral_secciones["mama_izquierda"], 
                        inmunohistoquimica_tumoral_secciones["mama_derecha"]] 
            for val in dic.values()
        ):
            for linea in self.informacion:
                
                # Verificar si estamos en diagnóstico
                if "diagnóstico" in linea:
                    # Extraer datos para cada marcador
                    for marcador, patron in patrones.items():
                        match = patron.search(linea)
                        if match:
                            valor = match.group(1).strip()
                            
                            # Solo asignar si no tenemos ya un valor (de biología tumoral)
                            if self.mama == "bilateral":
                                if inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] is None:
                                    inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] = valor
                                if inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] is None:
                                    inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] = valor
                            elif self.mama == "mama_izquierda":
                                if inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] is None:
                                    inmunohistoquimica_tumoral_secciones["mama_izquierda"][marcador] = valor
                            elif self.mama == "mama_derecha":
                                if inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] is None:
                                    inmunohistoquimica_tumoral_secciones["mama_derecha"][marcador] = valor

        self.data["inmunohistoquímica_tumoral"] = inmunohistoquimica_tumoral_secciones
        
    def __extraer_datos_estadia_tumoral(self):
        """
        Extrae y estructura los datos de estadía tumoral del texto procesado.

        Los datos se almacenan en el diccionario `data` bajo la clave "estadía_tumoral".

        Los datos a extraer suelen estar dentro de este tipo de secciones:
        - Extensión del tumor: Mama izquierda EC IIA (pT1c, pN1a, MO)
        - Extensión del tumor: Mama derecha EC IIA (pT2, NO, MO)
        - Extensión del tumor: cdi de mama izquierda ec iia ct2 -3.5 cm cn0
        """
        estadia_tumoral_secciones = {
            "mama_izquierda": {
                "ultrasonido": None,
                "mastografía": None,
                "centros_tumorales": None,
                "nódulos": None,
                "metástasis": None,
            },
            "mama_derecha": {
                "ultrasonido": None,
                "mastografía": None,
                "centros_tumorales": None,
                "nódulos": None,
                "metástasis": None,
            }
        }

        patron = r"(ct\d+\w*|pt\d+\w*|pn\d+\w*|n\d+\w*|cn\d+\w*|m\d+\w*)"
        
        for linea in self.informacion:
            linea = linea.strip()

            try:
                # Extraer datos de la extensión del tumor o diagnóstico
                if "extensión del tum" in linea or "diagnóstico" in linea:
                    # Buscar si hay información para ambas mamas o solo una
                    if self.mama == "bilateral":
                        try:
                            secciones = re.split(r"mama (izquierda|derecha)", linea, flags=re.IGNORECASE)
                            seccion_izquierda = secciones[2].strip()
                            seccion_derecha = secciones[4].strip()

                            # Expresión regular mejorada para capturar campos con guiones o caracteres especiales
                            campos_izquierda = re.findall(patron, seccion_izquierda, re.IGNORECASE)
                            for campo in campos_izquierda:
                                if campo.startswith(('pt','ct','t')):
                                    estadia_tumoral_secciones["mama_izquierda"]["centros_tumorales"] = campo
                                elif campo.startswith(('pn','n','cn')):
                                    estadia_tumoral_secciones["mama_izquierda"]["nódulos"] = campo
                                elif campo.startswith("m"):
                                    estadia_tumoral_secciones["mama_izquierda"]["metástasis"] = campo

                            campos_derecha = re.findall(patron, seccion_derecha, re.IGNORECASE)
                            for campo in campos_derecha:
                                if campo.startswith(('pt','ct','t')):
                                    estadia_tumoral_secciones["mama_derecha"]["centros_tumorales"] = campo
                                elif campo.startswith(('pn','n','cn')):
                                    estadia_tumoral_secciones["mama_derecha"]["nódulos"] = campo
                                elif campo.startswith("m"):
                                    estadia_tumoral_secciones["mama_derecha"]["metástasis"] = campo
                        except IndexError:
                            print("Error al procesar datos de mama bilateral para la estadia tumoral. Se identificaron la mención de mama izquierda y derecha, pero se procede de otra manera.")
                            # Extraer datos en base a "mama izquierda" o "mama derecha" si el try falla
                            if "mama izquierda" in linea:
                                campos_izquierda = re.findall(patron, linea, re.IGNORECASE)
                                for campo in campos_izquierda:
                                    if campo.startswith(('pt','ct','t')):
                                        estadia_tumoral_secciones["mama_izquierda"]["centros_tumorales"] = campo
                                    elif campo.startswith(('pn','n','cn')):
                                        estadia_tumoral_secciones["mama_izquierda"]["nódulos"] = campo
                                    elif campo.startswith("m"):
                                        estadia_tumoral_secciones["mama_izquierda"]["metástasis"] = campo

                            if "mama derecha" in linea:
                                campos_derecha = re.findall(patron, linea, re.IGNORECASE)
                                for campo in campos_derecha:
                                    if campo.startswith(('pt','ct','t')):
                                        estadia_tumoral_secciones["mama_derecha"]["centros_tumorales"] = campo
                                    elif campo.startswith(('pn','n','cn')):
                                        estadia_tumoral_secciones["mama_derecha"]["nódulos"] = campo
                                    elif campo.startswith("m"):
                                        estadia_tumoral_secciones["mama_derecha"]["metástasis"] = campo

                    elif self.mama == "mama_izquierda":
                        # Expresión regular mejorada para capturar campos con guiones o caracteres especiales
                        campos = re.findall(patron, linea, re.IGNORECASE)
                        for campo in campos:
                            if campo.startswith(('pt','ct','t')):
                                estadia_tumoral_secciones["mama_izquierda"]["centros_tumorales"] = campo
                            elif campo.startswith(('pn','n','cn')):
                                estadia_tumoral_secciones["mama_izquierda"]["nódulos"] = campo
                            elif campo.startswith("m"):
                                estadia_tumoral_secciones["mama_izquierda"]["metástasis"] = campo

                    elif self.mama == "mama_derecha":
                        # Expresión regular mejorada para capturar campos con guiones o caracteres especiales
                        campos = re.findall(patron, linea, re.IGNORECASE)
                        for campo in campos:
                            if campo.startswith(('pt','ct','ti')):
                                estadia_tumoral_secciones["mama_derecha"]["centros_tumorales"] = campo
                            elif campo.startswith(('pn','n','cn')):
                                estadia_tumoral_secciones["mama_derecha"]["nódulos"] = campo
                            elif campo.startswith("m"):
                                estadia_tumoral_secciones["mama_derecha"]["metástasis"] = campo

            except:
                print("Error en algún formato que imposibilita extraer los datos para la estadía tumoral")

        self.data["estadía_tumoral"] = estadia_tumoral_secciones

    
    def __extraer_datos_clasificacion(self):
        """
        Extrae y estructura los datos de clasificación del cáncer del texto procesado.

        Los datos se almacenan en el diccionario `data` bajo la clave "tipo".
        """
        clasificacion = {
            "mama_izquierda": {"clasificación": None, "descripcion": None},
            "mama_derecha": {"clasificación": None, "descripcion": None},
        }

        for linea in self.informacion:
            linea = linea.strip()

            # Buscar clasificación del cáncer
            if linea.startswith("diagnóstico"):
                # Quitar "Cáncer de mama bilateral." si está al inicio
                linea = re.sub(r"^cáncer de mama bilateral\.?", "", linea).strip()

                # Verificar si hay una barra "/" que indica ambas mamas
                if "/" in linea:
                    partes = linea.split("/")
                    for parte in partes:
                        parte = parte.strip()

                        # Extraer correctamente cada mama
                        if re.search(r"\bmi\b|\bmama izquierda\b", parte, re.IGNORECASE):
                            clasificacion["mama_izquierda"]["clasificación"] = parte.replace("diagnóstico: ", "").strip()
                        if re.search(r"\bmd\b|\bmama derecha\b", parte, re.IGNORECASE):
                            clasificacion["mama_derecha"]["clasificación"] = parte.replace("diagnóstico: ", "").strip()

                else:
                    # Buscar clasificación individual con más flexibilidad
                    match_izq = re.search(r"(?:diagnóstico:\s*)?(.*?)(?:\bmi\b|\bmama izquierda\b)\s*(.+)", linea, re.IGNORECASE)
                    match_der = re.search(r"(?:diagnóstico:\s*)?(.*?)(?:\bmd\b|\bmama derecha\b)\s*(.+)", linea, re.IGNORECASE)

                    if match_izq:
                        clasificacion["mama_izquierda"]["clasificación"] = f"{match_izq.group(1).strip()} {match_izq.group(2).strip()}".strip()
                    if match_der:
                        clasificacion["mama_derecha"]["clasificación"] = f"{match_der.group(1).strip()} {match_der.group(2).strip()}".strip()
                    else:
                        # Si no se encuentra ninguna coincidencia, guiarse por el atributo self.mama
                        if self.mama == "mama_izquierda":
                            clasificacion["mama_izquierda"]["clasificación"] = linea.replace("diagnóstico: ", "").strip()
                        elif self.mama == "mama_derecha":
                            clasificacion["mama_derecha"]["clasificación"] = linea.replace("diagnóstico: ", "").strip()

            if "extensión del tum" in linea:
                # Buscar mama izquierda
                match_izq = re.search(r"mama izquierda\s+([^\(]+)(?:\s*\(.*\))?", linea, re.IGNORECASE)
                # Buscar mama derecha
                match_der = re.search(r"mama derecha\s+([^\(]+)(?:\s*\(.*\))?", linea, re.IGNORECASE)
                
                if match_izq:
                    clasificacion["mama_izquierda"]["descripcion"] = f"{match_izq.group(1).strip()}"
                if match_der:
                    clasificacion["mama_derecha"]["descripcion"] = f"{match_der.group(1).strip()}"

        self.data["tipo"] = clasificacion

    def __aplicar_mapa_semantico(self):
        """
        Aplica mapas semánticos para completar datos que no se encontraron con los patrones directos.
        """
        # Mapa semántico para los campos GPCA
        mapa_gpca = {
            'g': ['gestacion', 'gestaciones', 'embarazos', 'embarazo'],
            'p': ['partos', 'parto'],
            'c': ['cesareas', 'cesáreas', 'cesarea', 'cesárea'],
            'a': ['abortos', 'aborto']
        }

        # mapa para la inmunohistoquimica tumoral
        mapa_inmunohistoquimica = {
            "triple negativo": {
                "re": "negativo",
                "rp": "negativo",
                "her2": "negativo"
            },
            "triple positivo": {
                "re": "positivo",
                "rp": "positivo",
                "her2": "positivo"
            },
        }


        # Verificar si las claves "g", "p", "c", "a" son None en self.data["antecedentes_personales"]["antecedentes_ginecológicos"]
        gpca_data = self.data.get("antecedentes_personales", {}).get("antecedentes_ginecológicos", {})
        
        if not all(gpca_data.get(letra) is not None for letra in ["g", "p", "c", "a"]):  # Verificar si alguna clave es None
            for linea in self.informacion:
                # Buscar términos relacionados con cada componente de GPCA
                for letra, terminos in mapa_gpca.items():
                    if gpca_data.get(letra) is None:  # Solo si no tenemos el dato
                        for termino in terminos:
                            if termino in linea:
                                # Extraer número asociado al término
                                # match = re.search(rf'{termino}\D*(\d+)', linea)
                                match = re.search(rf'(\d+)\s*\D*{termino}', linea, re.IGNORECASE)
                                if match:
                                    gpca_data[letra] = int(match.group(1))  # Actualizar el valor en gpca_data
                                    break  # Salir del bucle si ya encontramos el dato
        
        for letra in ["g", "p", "c", "a"]:
            if gpca_data.get(letra) is None:
                gpca_data[letra] = 0
        
        # Actualizar self.data con los cambios realizados en gpca_data
        self.data["antecedentes_personales"]["antecedentes_ginecológicos"] = gpca_data

        if (self.mama is not None) and (self.mama != "bilateral"):
            inmuno_data = self.data.get("inmunohistoquímica_tumoral", {}).get(self.mama, {})
        
            # Solo buscamos si alguno es None
            if any(inmuno_data.get(marcador) is None for marcador in ["re", "rp", "her2"]):
                print("Intentando llenar inmunohistoquímica tumoral con su mapa")
                for linea in self.informacion:
                    for termino, valores in mapa_inmunohistoquimica.items():
                        if termino in linea.lower():
                            for marcador, resultado in valores.items():
                                if inmuno_data.get(marcador) is None:
                                    inmuno_data[marcador] = resultado
            
            self.data["inmunohistoquímica_tumoral"][self.mama] = inmuno_data


    
    def __verificar_valores_nulos(self, ruta_log, nombre_caso):
        """
        Verifica los valores nulos en el diccionario self.data y guarda los resultados en un archivo de texto.

        Args:
            ruta_log (str): Ruta del archivo de texto donde se guardarán los valores nulos.
        """
        valores_nulos = {}

        # Función recursiva para recorrer los diccionarios anidados
        def verificar_subniveles(d, clave_principal=None):
            for clave, valor in d.items():
                if isinstance(valor, dict):
                    # Si el valor es un diccionario, llamamos a la función recurasiva
                    verificar_subniveles(valor, clave)
                elif clave not in ["ultrasonido", "mastografía"] and (valor is None or (isinstance(valor, (dict, list)) and not valor)):
                    # Si encontramos un valor nulo o vacío (excepto ultrasonido y mastografía), lo registramos
                    if clave_principal not in valores_nulos:
                        valores_nulos[clave_principal] = {}
                    valores_nulos[clave_principal][clave] = valor

        # Llamar a la función recursiva
        verificar_subniveles(self.data)

        if valores_nulos:
            # Asegúrate de que la ruta log es válida
            ruta_log = ruta_log + '/log.txt'

            try:
                with open(ruta_log, "a") as log_file:
                    log_file.write(f"Nombre del caso: {nombre_caso}\n")
                    log_file.write("Valores nulos encontrados:\n")
                    for clave_principal, subdiccionario in valores_nulos.items():
                        log_file.write(f"  - {clave_principal}:\n")
                        for subclave, valor in subdiccionario.items():
                            log_file.write(f"    - {subclave}: {valor}\n")
                    log_file.write("\n")
            except Exception as e:
                print(f"Error al escribir en el archivo de log: {e}")

    
    def convertir_txt_json(self, ruta_txt, ruta_destino):
        """
        Convierte un archivo de texto a un archivo JSON sin importar la cantidad de casos que contenga el txt.
        Crea tantos JSON como casos haya en el archivo de texto.
        Crea la carpeta de destino si no existe.

        Args:
            ruta_txt (str): Ruta del archivo de texto que se convertirá a JSON.
            ruta_destino (str): Ruta de la carpeta donde se guardarán los archivos
        """
        self.setrutaTxt(ruta_txt)
        self.setrutaDestino(ruta_destino)
        nombre_base = self.__extraer_nombre_txt().replace(".txt", "")

        os.makedirs(ruta_destino, exist_ok=True)  # Crear carpeta si no existe

        self.__limpiar_texto()

        if self.__hay_fases():
            # Si detecta fases, las separa
            self.__separar_fases()

            for idx, fase in enumerate(self.fases, start=1):
                self.informacion = fase  # Setea la fase actual como la información a procesar
                
                self.imprimir_info()

                self.__detector_pezones()
                self.__extraer_datos_antecedentes_personales()
                self.__extraer_datos_antecedentes_familiares()
                self.__extraer_datos_inmunohistoquímica_tumoral()
                self.__extraer_datos_clasificacion()
                self.__extraer_datos_estadia_tumoral()
                self.__aplicar_mapa_semantico()
                print('_________________________')
                nombre_json_fase = f"{nombre_base}_{idx}.json"  # Ejemplo: 123_1.json, 123_2.json
                self.__verificar_valores_nulos(ruta_destino, nombre_json_fase)
                self.__crear_json(nombre_json_fase)

                self.__limpiar_instancia(parcial=True)  # Limpia solo lo necesario para cada fase
        else:
            self.imprimir_info()
            # Solo un caso completo
            self.__detector_pezones()
            self.__extraer_datos_antecedentes_personales()
            self.__extraer_datos_antecedentes_familiares()
            self.__extraer_datos_inmunohistoquímica_tumoral()
            self.__extraer_datos_clasificacion()
            self.__extraer_datos_estadia_tumoral()
            self.__aplicar_mapa_semantico()
            print('_________________________')

            nombre_json = f"{nombre_base}.json"
            self.__verificar_valores_nulos(ruta_destino, nombre_json)
            self.__crear_json(nombre_json)

        self.__limpiar_instancia()

    def __limpiar_instancia(self, parcial=False):
            """
            Limpia el atributo "data" para evitar que se mezclen los datos de diferentes casos.
            Si parcial es True, limpia self.data y self.mama.
            """
            if parcial:
                self.data = {
                    "antecedentes_personales": {},
                    "antecedentes_familiares": {},
                    "estadía_tumoral": {},
                    "inmunohistoquímica_tumoral": {},
                    "tipo": {},
                }
                self.mama = None
            else:
                self.rutaTxt = None
                self.rutaDestino = None
                self.mama = None
                self.informacion = []
                self.fases = []
                self.data = {
                    "antecedentes_personales": {},
                    "antecedentes_familiares": {},
                    "estadía_tumoral": {},
                    "inmunohistoquímica_tumoral": {},
                    "tipo": {},
                }

    def imprimir_info(self):
        """
        Imprime las lineas que contenga el atributo "Información".
        """
        for linea in self.informacion:
            print(linea)

    def imprimir_json(self):
        """
        Imprime el atributo "data" en formato JSON.
        """
        print(json.dumps(self.informacion, indent=4, ensure_ascii=False))

    def __crear_json(self, nombreJSON):
        """
        Crea un archivo JSON con el atributo "data" que es un diccionario.

        Args:
            destino (str): Ruta del archivo JSON que se creará.
        """

        with open(os.path.join(self.rutaDestino, nombreJSON), 'w', encoding="utf-8") as file:
            json.dump(self.data, file, indent=4, ensure_ascii=False)

procesador = TextoJson()

#Obtener todos los archivos .txt en la carpeta especificada
# ruta_txts = r'D:\DOCUMENTOS\VirtualEnvPy\dataScience\source\Servicio\OCR_erik\TextoAJson\probando\*.txt'
# ruta_destino = r'D:\DOCUMENTOS\VirtualEnvPy\dataScience\source\Servicio\OCR_erik\TextoAJson\probando'

# for archivo_txt in glob.glob(ruta_txts):
#     procesador.convertir_txt_json(archivo_txt, ruta_destino)

ruta_txts = r'/home/josuevj/Documents/uni/servicio/sources/OCR_erik/TextoAJson/probando/expedientes/*.txt'
ruta_destino = r'/home/josuevj/Documents/uni/servicio/sources/OCR_erik/TextoAJson/probando/jsons'

for archivo_txt in glob.glob(ruta_txts):
    procesador.convertir_txt_json(archivo_txt, ruta_destino)

# procesador.convertir_txt_json(r'D:\DOCUMENTOS\VirtualEnvPy\dataScience\source\Servicio\OCR_erik\TextoAJson\nuevos_contetstos\expedientes\144923 (LISTO).txt', r'D:\DOCUMENTOS\VirtualEnvPy\dataScience\source\Servicio\OCR_erik\TextoAJson\probando')
# procesador.convertir_txt_json(r'/home/josuevj/Documents/uni/servicio/sources/OCR_erik/TextoAJson/expedientes/314084 (LISTO).txt', r'/home/josuevj/Documents/uni/servicio/sources/OCR_erik/TextoAJson/json')
# Out:
# emc / 314084 / 56 años / dra. martínez
# diagnóstico: cdi ct4d, cn3c, cm1 triple negativo
# tabaco: negado
# alcohol: ocasional
# drogas: negado
# ahf oncológicos: negados
# ago: menarca 12 años
# fum: 50 años g1 p0 c0 a0 d
# aco: negado
# estado hormonal: postmenopáusica.
# comorbilidades: 1. negado
# 12.2022: disfagia esofágica, náuseas y vómito, así como pérdida de peso no intencionada de 3 kg (de 49 a 46 kg).
# 03.2023: notó un aumento significativo en el volumen de una tumoración en la mama izquierda (refiere que esta tumoración estaba presente y estable desde 2013), además de enrojecimiento en la piel de la mama.
# 24.03.23: mg bi-rads 3
# 28.03.23 fucam biopsia trucut de la tumoración mamaria izquierda: carcinoma ductal infiltrante sin patrón específico, grado 3, poco diferenciado, ipn- ilv- incmnsz revisión: rhp: carcinoma ductal infiltrante, sin patrón especifico, grado 3, carcinoma ductal in situ: no identificado, invasión linfática y/o vascular: no identificado. re 0%, rp 0%, her-2 negativo, ki67 70%, gata3 positivo, p16 positivo focal, ck5/6 positivo.
# 08.05.23 mg: en cll se observa nódulo sólido ecogénico con zonas hipoecogenicas centrales, que mide 4 x 2.8 x 3.81 cm, se observan además en interlínea de cuadrantes internos y externos, así como en los cuadrantes inferiores varios nódulos hipoecogénicos, confluentes en relación con enfermedad multicéntrica. en hueco axilar izquierdo ese observa conglomerado ganglionar.
# 08.05.23: pet ct con fdg tumoración mamaria izquierda hiper metabólica, con invasión a la pared torácica, compatible con actividad neoplásica primaria conocida. adenopatías cervicales izquierdas, axilares, retropectorales y en cadena mamaria interna ipsilateral, con incremento focal del metabolismo, en relación con depósitos secundarios. secreciones obstructivas en bronquio del lóbulo medio, con atelectasia secundaria con incremento difuso del metabolismo, a descartar sobreinfección. incremento difuso del metabolismo de la médula ósea del esqueleto axial e inversión del metabolismo hepatoesplénico, de probable etiología reactiva.
# 09.03.23: fit <2.6, bt 0.69, alt 49, fa 502, ggt 150, albumina 2.50, creatinina 0.46, hb 7.4, htc 24, vcm 76, leucocitos 5.6, neutrófilos 3.74, plaquetas 745.000
# extensión del tumor: t4d, cn3, m1 (enfermedad ganglionar no regional)
# estado hormonal: posmenopáusica
# extensión del tumor: pt1b, pn0, m0 riesgo clínico bajo nn
# estado hormonal: premenopáusica
# Se detectó mama: None
# _________________________
# epfv / 313894 / 54 años / dra. martínez
# diagnóstico: cdis de bajo grado de mama izquierda
# comorbilidades: 1. dislipidemia mixta (2022) 2. prediabetes (2022)
# tabaco: negado
# alcohol: ocasional
# drogas: negado
# ahf oncológicos: - padre con diagnóstico de cáncer de próstata a los 55 años
# menarca 13 años / fum 2018
# g2 p2 c0 a0
# mpf diu con levonogestrel por 7 años / trh: no
# estado hormonal: postmenopáusica
# 12.2022 mmg asimetría focal en mama izquierda asociada a calcificaciones pleomórficas, correspondiente a bi- rads 4b incmnsz
# 01.2023 mmg en mama izquierda grupos de calcificaciones amorfas en interlínea de cuadrantes internos y cse, lineales ramificadas en interlínea de cuadrantes internos tercio medio. en regiones axilares se identifican ganglios de morfología oval, adecuadas dimensiones y con preservación del centro radiolúcido. hallazgos correspondientes a categoría birads 4c.
# 10.02.23 biopsia trucut de mama izquierda; se colocó marcador metálico (ultraclip) en sitio de biopsia de cuadrantes internos. rhp: cdis cribiforme y sólido, grado 2, microcalcificaciones +, re 90%, rp 70% q/l.6enqoq n0 hay dgt oram wa ” y, ne a: n
# extensión del tumor: cdis de mama izquierda
# biología tumoral: re 90%, rp 70%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# Intentando llenar inmunohistoquímica tumoral con su mapa
# _________________________
# lkr / 83432 / 89 años / dr. soto
# diagnóstico: cdi de mama izquierda ec ia (t1cn0) re 95%, rp1%, her2 — (1+)
# comorbilidades: 1. diabetes tipo 2 2. hipertensión arterial sistémica 3. insuficiencia venosa periférica ceap 3 4. antecedente de trombosis venosa profunda izquierda s 9.0
# ahf oncológicos: hija con cáncer de cabeza y cuello diagnosticado a los 60 años, hija falleció cáncer de mamá a los 29 años; papá con cáncer de próstata a los 75 años
# tabaco: it 20, suspendido hace 40 años
# alcohol: negado
# drogas: negado
# 25.08.23 ufcm consulta: respecto al hallazgo del aneurisma en carótida interna, la paciente está asintomática, sin alteración en nervios craneales, se comentó el caso con neurocirugía y neurología quienes sugieren enviarla a la consulta de neurología de pv para seguimiento, se calcula phases score de 4 puntos con un riesgo de ruptura de 0.9% a 5 años, iniciamos tratamiento con antihipertensivo por has de reciente diagnóstico. tiene ecott brogramado es 10.11.23, solicito ekg. oraumoa en cie de mama izquierda se palpa tumor de 40 x 30 mm pétreo y fijo. se palpa adenopatía axilar izquierda de 12 mm, no dolorosa, móvil.
# extensión del tumor: cdi de mama izquierda ec ib ct2- 4 cm cn1
# biología tumoral: luminal b, her2- re 0%, rp 70%, her2 1+ (-), ki67 30%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# _________________________
# magdg / 247086 / 64 años / dra. verduzco
# diagnóstico: cdi de mama derecha ec ia (t1cn0mo) ihq rp+, blueprint triple negativo or. mmooq
# tabaco: negado
# alcohol: negado
# drogas: negado
# ahf oncológicos: abuelo paterno cáncer de próstata desconoce edad), papá con cáncer de próstata (71 años), hermana con linfoma ne (57 años)
# menarca 16 años
# fum 55 años
# g7 (primero a los 22 años) p0 c3 a4
# mpf levonogestrel im 1 años / thr negada
# estado hormonal: postmenopáusica
# comorbilidades: sobrepeso, hipotiroidismo, dlp mixta, osteoartrosis
# diagnóstico: cdi de mama derecha ec ia (t1cn0mo) ihq rp+, blueprint triple negativo qyl.eamgoo
# tabaco: negado
# alcohol: negado
# drogas: negado
# ahf oncológicos: abuelo paterno cáncer de próstata desconoce edad), papá con cáncer de próstata (71 años), hermana con linfoma ne (57 años)
# menarca 16 años
# fum 55 años
# g7 (primero a los 22 años) p0 c3 a4
# mpf levonogestrel im 1 años / thr negada
# estado hormonal: postmenopáusica
# comorbilidades: sobrepeso, hipotiroidismo, dlp mixta, osteoartrosis 2017 mmg birads 2
# 12.2022 mmg (externa) nódulo en mama derecha.
# 12.2022 biopsia trucut de mama derecha: cdi de mama tipo medular, re-, rp 90%, her2 -, ki67 80%, gata 3+.
# 14.01.23 pet/ct (externo) seat
# 28.01.23 cc + gc. rhp cdi g3, 1.2 cm, re-, rp+, her2-, ki67 80%, gl 0/3.
# 02.2023 mammaprint: riesgo alto
# 19.04.23-21.06.23 c1-c4 tc revisión de laminillas: cdi spe g3 (3+3+3=9), tamaño del tumor de 1.2x0.9 cm, cdis -. mq-. gl 0/3. pt1cno. q/rl.6emnqo0o n0 hay dgt your results ta e a a er status: n/a pr status: n/a her2 status: n/a. blueprint” subtype: basal-typo basa-type summary of results: high risk basal-type _ marmaprit 70-gene risk of recurronce —— biveprint 80-geno molecular subtype high risk basal-type predictod risk of without adjuvant systematic treatment observed outcome based on clinical studies* | apoco e for pañerts with mammaprint high risk ma mo 5-year metastasis-free survival" absolute chemotherapy benefit" hormone therapy + chemo. ange 93% >12% il fon ot recurrence 355333353 pr récsron merry patlent's mammaprint result: high risk average 10-yoar risk of recurrence untreated": 29% patients mammaprint index: mpi) 0.741
# mama derecha con cicatriz por cc con bordes bien afrontados, sin datos de infección, sin lesiones palpables.
# extensión del tumor: cdi de mama derecha ec ia ptic-1.2 cm pn0
# biología tumoral: triple negativo re 0%, rp 80%, her2 -, ki67 80%
# estado hormonal: postmenopáusica
# Se detectó mama: mama
# 14.12.21 tac tap: incremento en la densidad retroareolar izquierdo, coexiste adenopatía axilar ipsilateral, en relación con neoplasia conocida. seat
# 13.12.21 -02.2022 s1-12 cbp/t
# 22.03.22-24.05.22 c1-c4 ac
# 08.06.22 mg/usg con respuesta radiológica completa
# 28.06.22 cc mama izquierda + ganglio centinela. rhp (q-22-3372): ypto n0 ozono
# 16.06.23 mmg/us: birads 4c. nódulo en mama izquierda de 5.3 mm y engrosamiento de piel y complejo pezón- areola. biopsia rhp (q23-4032): cdi spe g3 (3+2+2=8), ilv(-), ipn(-). ihq re (-) rp (-) her2 (-) ki 67 90%. referido como complejo areola pezón: tejido adiposo con hemorragia.
# 05.07.23 pet ct (preliminar): nódulo en mama derecha en relación a primario conocido. adenopatías axilares y en cadena mamaria interna. ozono
# mama izquierda con equimosis asociada a biopsia. engrosamiento del complejo areola-pezón. lesión palpable de 6 cm
# extensión del tumor: cdi de mama izquierda ec /iic t1b — 0.53 cm n3b - axilares y cadena mamaria
# biología tumoral: triple negativo re 0%, rp 0%, her2 -, ki67 90%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# _________________________
# lsro / 169576 / 64 años / dra. verduzco
# diagnóstico: cdis de mama izquierda
# tabaco: |t 35, suspendido hace 14 años
# alcohol: ocasional
# drogas: negadas
# ahf oncológicos: mamá con probable cáncer de páncreas (66 años).
# menarca 13 años
# fum 35 años
# g2 (primer embarazo = 20 años) p0 c2 a0
# aco qurante 2 años y trh negada
# estado hormonal: postmenopáusica
# comorbilidades: 1. esófago de barrett esófago de barrett 4. neuralgia del trigémino 2. hipotiroidismo primario 5. dislipidemia mixta 3. osteoporosis
# diagnóstico: cdis de mama izquierda
# tabaco: |t 35, suspendido hace 14 años
# alcohol: ocasional
# drogas: negadas
# ahf oncológicos: mamá con probable cáncer de páncreas (66 años).
# menarca 13 años
# fum 35 años
# g2 (primer embarazo = 20 años) p0 c2 a0
# aco qurante 2 años y trh negada
# estado hormonal: postmenopáusica
# comorbilidades: 1. esófago de barrett esófago de barrett 4. neuralgia del trigémino 2. hipotiroidismo primario 5. dislipidemia mixta 3. osteoporosis
# 16.06.23 mmg (tamizaje): implantes con hallazgos que sugieren ruptura intracapsular bilateral. grupo de calcificaciones gruesas heterogéneas en mama izquierda no evidentes en estudio previo se sugiere biopsia. categoría birads 4 b.
# 26.06.23 biopsia de calcificaciones de mama izquierda. rhp (q-23-4292) cdis patrón comedo, sólido y cribiforme, g3, microcalcificaciones presentes. ihq re 2%. hallazgos adicionales: mastitis crónica granulomatosa, tinción zn -. n0 hay dgt mamas asimétricas
# extensión del tumor: cdis de mama izquierda
# biología tumoral: re 2%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# Intentando llenar inmunohistoquímica tumoral con su mapa
# _________________________
# lsro / 169576 / 64 años / dra. verduzco
# diagnóstico: cdis de mama izquierda
# comorbilidades: 4. osteoporosis 1. esófago de barrett - última edg 11.2022. rhp (q22- 5. neuralgia del trigémino 7073): esófago de barrett sin displasia. 6. otoesclerosis 2. hipotiroidismo primario 7. dislipidemia mixta 3. esteatosis hepática 8. ruptura tendinosa del manguito rotador oro b.o-
# tabaco: it 35, suspendido a los 50 años
# alcohol: ocasional
# drogas: negadas
# ahf oncológicos: mamá con cáncer de páncreas 66 años)
# menarca 13
# fum 35
# g2 (primer embarazo 20 años) p0 c2 a0
# aco durante 2 años y trh negada
# estado hormonal: postmenopáusica
# 16.06.23 mmg (tamizaje): implantes con hallazgos que sugieren ruptura intracapsular bilateral. grupo de calcificaciones gruesas heterogéneas en mama izquierda no evidentes en estudio previo se sugiere biopsia. categoría birads 4 b.
# 26.06.23 biopsia de calcificaciones de mama izquierda. rhp (q-23-4292) cdis patrón comedo, sólido y cribiforme, g3, microcalcificaciones +. ihq re 2%. hallazgos adicionales: mastitis crónica granulomatosa, tinción zn -.
# 18.07.23 ufcm: se sesionó el caso de la paciente laura silvia renteria, paciente con cdis de mama izquierda. por parte del servicio de radiología se comenta que las calcificaciones se encuentran en interlínea de cuadrantes superiores, por parte de cirugía oncológica se considera candidata a cc de mama sin ganglio centinela. veremos en la consulta de la doctora verduzco el 21.07.23 para informar las conclusiones de la sesión y enviar a la consulta de cirugía oncológica.
# 21.07.23 onco pv programada para cirugía el 17.08.23.ecog 0.
# 17.08.23 cirugía conservadora de mama izquierda + marcaje con arpón sin ganglio centinela. rhp (q-23-5918): cdis patrón comedo y cribiforme, g3, con necrosis central, mq -, re + 2%. o/2umoo yo mama izquierda con cicatriz transversal con bordes bien afrontados en interlinea de cuadrantes superiores. no se palpan masas ni adenopatías ipsilaterales
# extensión del tumor: cdis de mama izquierda
# biología tumoral: re 2%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# Intentando llenar inmunohistoquímica tumoral con su mapa
# _________________________
# mdjgp / 314707 / 65 años / dra. martínez
# diagnóstico: carcinoma ductal infiltrante de mama derecha ec ia (ct1b cn0 m0) luminal b, her2 2+
# tabaco: it 10.5, suspendido 2001
# alcohol: negado
# drogas: negado
# menarca 13 años / fum 2005
# g2 p1 c1 a0
# aco: negados
# trh: negados
# estado hormonal: postmenopáusico
# comorbilidades: fibromialgia (2006); diabetes tipo 2 (2005); dislipidemia mixta (2010); trastorno depresivo mayor 2006) tratamiento: metformina 1 g bid, sitagliptina 100 mg qd, dapaglifozina 10 mg qd, fenofibrato 200 mg qd, sertralina 25 mg qd, vitamina d 4000 ul qd
# 29.05.23 mmg de tamizaje (externa) birads o incmnsz
# 12.06.23 usg: mama derecha con nódulo hipoecoico en r9 de bordes microlobulados con eje mayor de 5.9 mm. bi-rads 4c.
# 12.06.23 biopsia de mama derecha por trucut. rhp (q-23-3878) cdi g2 (3+2+1 = 6), ilv-, ipn -, cdis+. ihq re 90% rp 15% her2 indeterminado (sish pendiente), kl67 15%. glen o revisión de estudios de imagen revisión de archivo de patología n0 hay dgt
# extensión del tumor: cdi de mama derecha ec ia ct1b -— 0.59 cm cn0
# biología tumoral: luminal b re 90%, rp 15%, her2 2+ (sish pendiente), ki67 15%
# estado hormonal: postmenopáusica
# diagnóstico: originaria y reside
# ahf oncológicos cáncer gástrico ( antecedente de c hermana antecea
# menarca 13 año
# -g2 p1 c1 a0 - mpf: diu de cc - estado hormo
# comorbilidades: 1. fibromialgia (: 2. diabetes tipo 3. dislipidemia n 4. trastorno deb go 53-8-9-o nte: chiapas y cdmx insabi
# diagnóstico: cdi de mama derecha ec ia (pt1c pn0) luminal a abuela materna antecedente de lesconoce edad), papa con ncer de próstata (80 años), ente de cáncer gástrico (45 años)
# tabaco: it 10, suspendido hace 22 años
# alcohol: negado
# drogas: negado
# s / fum 2005
# ahf oncológicos: abuela materna antecedente de cáncer gástrico (desconoce edad), papa con antecedente de cáncer de próstata (80 años), hermana antecedente de cáncer gástrico (45 años)
# tabaco: it 10, suspendido hace 22 años
# alcohol: negado
# drogas: negado
# menarca 13 años / fum 2005
# -g2 p1 c1 a0 - mpf: diu de cobre e implante de levonogestrel - estado hormonal: postmenopáusica
# 29.05.23 mmg de tamizaje (externa) birads o incmnsz
# 12.06.23 usg: mama derecha con nódulo hipoecoico en r9 de bordes microlobulados con eje mayor de 5.9 mm. bi-rads 4c.
# 12.06.23 biopsia por trucut. rhp (q-23-3878) cdi g2 (3+2+1 = 6), ilv-, ipn -, cdis+. ihq re 90% rp 15% her2 indeterminado (sish no amplificado), ki67 15%.
# 30.06.23 ufcm consulta: el tumor no genera síntomas. g8 16 puntos (>3 medicamentos). abvd 6/6 aivd 7/8 (no maneja sus finanzas). ecog 1.
# 11.07.23 ufcm a pesar de no tener resultado de sish, se considera candidata a cirugía de entrada al tratarse de un tumor t1b. por parte del servicio de cirugía oncológica se propone cc de mama derecha con gc.
# 12.07.23 qx onco: se programa para el 07.08.23 para ccm + gc + marcaje con arpón por no ser coincidente la lesión palpable con la reportada en estudios de imagen.
# 14.07.23 onco: candidata a consejería genética por antecedentes heredofamiliares de cáncer en 2 familiares de primer grado y uno de segundo grado.
# 07.08.23 cirugía conservadora de mama + ganglio centinela. rhp (q-23-5584) cdi spe, g1 (2+2+1 = 5), 1.5x 1.3 x 1.4 cm, ilv - mq -, gl 0/3 (pt1c), ihq re 90%, rp 80%, her2 1+ (-), ki67 2% o/laeamo0oo
# extensión del tumor: cdi de mama derecha ec ia ptic-1.5 cm pno0
# biología tumoral: luminal a re 90%, rp 80%, her2 -, ki67 2%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_derecha
# _________________________
# mgie / 188584 / 60 años / dra. chávarri
# diagnóstico: originaria y residente: ciudad de méxico
# diagnóstico: carcinoma ductal infiltrante, t1b, pn0, m0. ec ia
# tabaco: positivo durante 15 años, 10 cigarros/dia, suspendido hace 10 años;
# alcohol: ocasional
# drogas: negado
# ahf oncológicos: negados
# ago: menarca 11 años cirugías: amigdalectomía (11 años), cesárea (29
# fum: 48 años años), colecistectomía (31 años), vats resección de - nódulo pulmonar (rhp - externo - negativo para g1 p0 c1 a0 (fecha de primer embarazo: a los 29 años), no malignidad), p0 de resección de colgajo cutáneo
# dio lactancia / aco durante 1 años. perianal (2018)
# comorbilidades: 1. dislipidemia mixta en tratamiento con ezetimiba 10 mg qd, atorvastatina 40 mg qd) 2. trastorno de ansiedad generalizada. 3. osteoartritis,
# tabaco: positivo durante 15 años, 10 cigarros/dia, suspendido hace 10 años;
# alcohol: ocasional
# drogas: negado
# ahf oncológicos: negados
# ago: menarca 11 años
# fum: 48 años g1 p0 c1 a0 (fecha de primer embarazo: a los 29 años), no
# dio lactancia / aco durante 1 años.
# comorbilidades: 1. dislipidemia mixta en tratamiento con ezetimiba 10 mg qd, atorvastatina 40 mg qd) 2. trastorno de ansiedad generalizada. 3. osteoartritis,
# 25.05.23 usg/mmg: birads 4c. en el radio de las 3 a 2 cm del pezon se observa un nódulo hipoecoico de 10.6 mm en su diámetro máximo.
# 06.06.23 biopsia de mama de mama izquierda (externo): cdi spe, g2 (suma 6), cdis no identificado. ipn +, ilv -, microcalcificaciones-. ihq: re 99%, rp 99%, her2 3+ (positivo), ki67 10%.
# 20.06.23 cc de mama izquierda + gc. rhp (externo): cdi spe g2 (3+2+1=6) con componente micropapilar. cdis - tamaño del tumor 0.9 cm. ilv-, ipn+, mq -. 3 gl todos negativos.
# 04.07.23 pet ct pet-ct unam. incremento anormal del metabolismo en amígalas palatinas, con suvmáx de 7.0, se asocian con incrementos ganglionares cervicales en nivl ib, iia, iib, vi de hasta 7mm con suv máx de 2.3. glándula mamaria izquierda con cambios postquirúrgicos, en topografía de cuariante inferior interno con presencia de al menos dos imágnes continuas que sugieren colección residual y muestran morfología irregular, márgenes imprecisos, asociado con densidad de aire. medidas de 18x22mm. cambios posquirúrgicos en la región axilar izquierda con suv máx de 1.9, crecimientos axilares derechos en nivel | que conservan morfología e hilio graso, eje corto de hasta 5mm, suvmáx 1.4 revisión de patología incmnsz. rhp q23-4759. biopsia por trucut de mama:. carcinoma ductal infiltrante sin patrón específico, grado 2. cdis negativo. ilv (-) ihq: re 90%, rp 70%, her2 1+ negativo, ki67 20% cuadrantectomía de mama izquierda. carcinoma ductal infiltrante sin patrón específico. grado 2 (3+2+1) tamaño del tumor 1 cm en su eje mayor medido sobre laminilla. cdis presente con patrón cribiforme. márgenes quirúrgico negativos. se evaluaron 3 ganglios centinela, ninguno con metástasis (0 de 3). ihq: re 90% 3+, rp 70% 3+, her2 1+, ki67 25%
# 12.07.23
# Se detectó mama: None
# _________________________
# egm / 313895 / 37 años / dra. chavarri
# diagnóstico: originaria y resis
# ahf oncológico
# menarca 12 añ
# g1 p0 c0 a1 (
# aco negado
# estado hormo
# comorbilidades 1. migraña con 2. hipertensión 3. probable artr 4. trastorno ob oy eelo lente: chiapas erciante insabi stico: cdi de mama derecha ec ia (t3 n1(f)/m0) luminal b, her2 positivo
# tabaco: negado 5: negado alcohol: ocasional
# drogas: negado
# os / fum 21.03.23
# ahf oncológicos: negado
# tabaco: negado
# alcohol: ocasional
# drogas: negado
# menarca 12 años / fum 21.03.23
# g1 p0 c0 a1 (embarazo a los 27 años)
# aco negado
# estado hormonal: premenopáusica, paridad
# 03.2022 autopalpación de lesión en mama derecha 2022 us mamario: reporte verbal de fibrosis
# 03.2023 crecimiento del tamaño de la lesión en mama derecha
# 16.03.2023 us/mmg tejido mamario con ecotextura heterogénea. cse de mama derecha con dos zonas de distorsión de la arquitectura, en el radio 10 línea a se observa una zona focal de sombra acústica posterior de 1.2 x 0.7 cm y en el radio 10 línea c se observa otra de 1.4 x 1.3 cm. ganglios axilares derechos con datos sugestivos de infiltración tumoral. bi-rads 5
# 03.2023 biopsia trucut de de mama derecha + baaf de un ganglio axilar derecho. rhp: carcinoma ductal infiltrante sin patrón específico moderadamente diferenciado, grado ii, ilv-. ganglio axilar con células epiteliales atípicas sugerentes de metástasis de carcinoma ductal. incmnsz revisión de laminillas (q-23-2254): cdi de tipo no específico. g2 (2+3+2), con cdis presente, ilv-, ipn-. ihq re 90%, rp 0%, her2 ++ (indeterminado), ki67 30%. sish her2 amplificado revisión baaf de ganglio axilar: (ba-23-075): carcinoma metastásico
# 10.04.23 mmg birads 6. hallazgo compatible con tumor primario de mama multicéntrico con lesión mayor de 5.7 cm en cse en la mama derecha. ganglios axilares ipsilaterales sugestivos de infiltración.
# 12.04.23 fevi 61%, sgl -21%
# 13.04.23 pet/ct: múltiples lesiones en mama derecha correspondientes a actividad neoplásica conocida enfermedad multicéntrica). adenopatías axilares y retropectoral derechas compatibles con depósitos secundarios. pae o
# 03.05.23 c1 tchp
# 04.05.23 gosereline 10.8mg
# 12.05.23 panel genético coh
# 24.05.23 c2 tchp
# 13.06.23 mmg ganglios axilares derechos sin reforzamiento en estudio actual. reforzamiento mamas en mama derecha de menor tamaño. respuesta parcial. categoría birads 6.
# 14.06.23-16.08.23 c3-c6 tchp
# 01.09.23 mmg/us: microcalcificaciones finas pleomórficas en mama derecha en cuadrantes superior externo. nódulo hipoecoico en mama derecha en topografía de tumor primario que mide 0.7 cm. respuesta parcial. hallazgos correspondientes a categoría birads-6. n0 hay dgt
# extensión del tumor: cdi de mama derecha ec iia ct3 - 5.7 cm cn1 (f)
# biología tumoral: luminal b her2 + re 90%, rp 0%, her2 ++ (sish amplificado), ki67 30%
# estado hormonal: premenopáusica
# diagnóstico: cdi de mama derecha ec iia luminal b, her2 positivo
# comorbilidades: 1. migraña con aura (2008) 2. hipertensión arterial sistémica (2015) 3. probable artritis reumatoide (2019), fr <10, anti-ccp 0.1 (negativos, 2023) 4. trastorno obsesivo compulsivo (2022)
# ahf oncológicos: negados
# tabaco: negado
# alcohol: ocasional
# drogas: negado
# menarca 12 años / fum 21.03.23
# g1 p0 c0 a1 (edad de embarazo 27 años) - aco: negado. - estado hormonal: premenopáusica, paridad satisfecha
# 03.2023 crecimiento del tamaño de la lesión en mama derecha
# 16.03.2023 us/mmg tejido mamario con ecotextura heterogénea. cse de mama derecha con dos zonas de distorsión de la arquitectura, en el radio 10 línea a se observa una zona focal de sombra acústica posterior de 1.2 x 0.7 cm y en el radio 10 línea c se observa otra de 1.4 x 1.3 cm. ganglios axilares derechos con datos sugestivos de infiltración tumoral. bl-rads 5
# 03.2023 biopsia trucut de de mama derecha + baaf de un ganglio axiladerecho. rhp: carcinoma ductal infiltrante sin patrón específico moderadamente diferenciado, grado ii, ilv-. ganglio axilar con células epiteliales atípicas sugerentes de metástasis de carcinoma ductal. incmnsz revisión de laminillas (q-23-2254): cdi de tipo no específico, g2 (2+3+2), con cdis presente, ilv-, ipn-. ihq re 90%, rp 0%, her2 ++ (indeterminado), ki67 30%. sish her2 amplificado revisión baaf de ganglio axilar: (ba-23-075): carcinoma metastásico
# 10.04.23 mmg birads 6. hallazgo compatible con tumor primario de mama multicéntrico con lesión mayor de 5.7 cm en cse en la mama derecha. ganglios axilares ipsilaterales sugestivos de infiltración.
# 12.04.23 fevi 61%, sgl -21%
# 13.04.23 pet/ct: múltiples lesiones en mama derecha correspondientes a actividad neoplásica conocida enfermedad multicéntrica). adenopatías axilares y retropectoral derechas compatibles con depósitos secundarios. q/r/rl0henqo en mama derecha, en cse, se palpa lesion de aproximadamente 6 cm no se palpan adenopatías axilares, claviculares ni cervicales
# extensión del tumor: cdi de mama derecha ec iia ct3-6cm c(f)n1
# biología tumoral: luminal b, her2+ re 90%, rp 0%, her2 amplificado, ki67 30%
# estado hormonal: premenopáusica
# Se detectó mama: mama_derecha
# _________________________
# lemr / 307012 / 54 años / dra. martínez
# diagnóstico: cdis de mama izquierda
# tabaco: negado
# alcohol: negado
# drogas: negado
# ahf oncológicos: negados
# menarca 15 años
# fum 50 años
# g3 p0 c3 a0
# aco durante 4 años
# estado hormonal: postmenopáusica
# comorbilidades: 1. lmc en fase crónica (2014) —> en fase blástica por sarcoma mieloide (03.2021) — p0 alotrasplante dcr - 10.03.21 inducción 7+3 (citarabina + daunorribicina) + nilotinib — consolidación con daac dosis densas de citarabina + daunorrubicina
# 13.06.23 mmg/us cuadrante superio reforzamiento no r
# 14.06.23 biopsia « microcalcificacion
# 04.07.23 ufcm se candidata a maste
# 24.08.23 mastectc 0.6 x 0.2 cm, patri actualmente hosp
# 13.09.23 tac tóre asocia a engrosan subcutáneo adyac
# 14.09.23 drenaje « intentos. qosy0.0mo € s: calificaciones lineales ramificadas y pleomórficas en interlinea de cuadrantes en interlínea ores tercio posterior mama izquierda inferiores de distribución segmentaria que muestra masa heterogéneo. sin adenopatías. birads 5. de microcalcificaciones de mama izquierda. rhp (q-23-3946): cdis patrón sólido comedo, g3, nes presentes en conducto no neoplásico. ihq re 2+ (+) se revisaron las imágenes documentando calcificaciones multicéntricas por lo que se consideró tectomía radical modificada de mama izquierda con ganglio centinela. tomía izquierda preservadora de piel + gc (renio) + colocación de implante. rhp (q23-6102): cdis rón cribiforme y comedo, g3, mq - (el más cercano a 1 cm), gl 0/14 (ptisno). re 80% pitalizada por itb (aislamiento e. coli sensible > tx con ceftriaxona) rax: colección retropectoral izquierda mide 16.8 x 11.1 x 2.2 cm, encapsula implante mamario; se imiento cutáneo con escasos focos de gas a este nivel y estriación de la grasa del tejido celular icente y de hemitórax ipsilateral. de colección periprotésica guiada por ultrasonido. no se logro drenaje a pesar de múltiples a4 ) mama izquierda con presencia de herida quirúrgica, en el borde medial se evidencia salida de material purulento. dolor a la palpación de axila izquierda.
# extensión del tumor: cdis de mama izquierda
# biología tumoral: re 80%
# estado hormonal: postmenopáusica
# extensión del tumor: cdis de mama izquierda
# biología tumoral: re 80%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# Intentando llenar inmunohistoquímica tumoral con su mapa
# _________________________
# mage / 314896 / 61 años / dra. verduzco
# diagnóstico: originaria y residente: ciudad de méxico.
# diagnóstico: cdi de mama izquierda eg mi b (t4b n1 mx) re+/her2 negativo
# ahf oncológicos: negados. hen it dd hace 17 años.
# alcohol: negado
# drogas: negado
# menarca 11 años
# fum 51 años g4 p3 c1 a0 (edad de primer embarazo: 16 años) cirugías: cesárea (1995), cirugía de
# aco 3 años, posteriormente cambio a diu t de cobre y al ropas a (2008); faco +
# final utilizo parche durante 5 años / trh negadas ( )
# comorbilidades: hipertensión arterial sistémica (1998). diabetes mellitus tipo 2 (2019). arritmia en estudio. medicamentos: metformina 850mg 1-1-1, telmisartán/amlodipino 40/5mg 1-0-0, atenolol 25mg 1-0-0
# tabaco: it <1, suspendido hace 17 años.
# alcohol: negado
# drogas: negado
# ahf oncológicos: negados.
# menarca 11 años
# fum 51 años
# g4 p3 c1 a0 (edad de primer embarazo: 16 años)
# aco 3 años, posteriormente cambio a diu t de cobre y al
# final utilizo parche durante 5 años / trh negadas
# comorbilidades: hipertensión arterial sistémica (1998). diabetes mellitus tipo 2 (2019). arritmia en estudio. medicamentos: metformina 850mg 1-1-1, telmisartán/amlodipino 40/5mg 1-0-0, atenolol 25mg 1-0-0
# 07.2022 autopalpación de tumor en mama izquierda
# 31.05.23 mmg birads 5
# 06.06.23 biopsia trucut de mama izquierda. rhp (externo) cdi spe, grado 2, cdis ausente, ilv -, ipn -. ihq: re: rp +++; her2: -; ki-67:15%. ps incmnsz rhp q-23-4878: carcinoma ductal infiltrante spe, grado 2 (3+2+1), cdis no identificado, ilv no se identifica, microcalcificaciones ausentes. re 90% 3+, rp 20% 2+, her2 1+ (negativo), ki67 10%.
# 21.07.23 onco: asintomática. independiente para actividades básicas e instrumentadas, aún trabaja.ecog 0.
# 24.07.23: pet ct con fdg: lesión en mama izquierda hiper metabólica compatible con actividad neoplásica primaria conocida. adenopatías axilares izquierdas con pérdida de la morfología e hiper metabolismo en relación con depósito secundario. no se identifican datos de enfermedad a distancia. lesión adrenal derecha sin incremento del metabolismo de etiología benigna, a considerar adenoma.
# 26.07.23: mg nódulo hiperdenso, ovoideo, indistinto que condiciona retracción de la piel, eje máximo de 4.7 cm. se realiza baaf. rhp: carcinoma metastásico. i
# biología tumoral: grado 2, re 90%, rp 20%, her2 1+, ki67 10%
# extensión del tumor: ct4b f)n1 (adenopatia axilar móvil) m0
# biología tumoral: grado 2, re 90%, rp 20%, her2 1+, ki67 10%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_izquierda
# _________________________
# maf / 209167 / 51 años / dra. martínez
# ...
# 14.08.2023 geriatría oncológica: persiste con neuropatía sensitiva g2 (hipoestesias de manos y pies). funcionalidad: abvd 6/6. aivd 8/8. sin caídas.
# biología tumoral: g3, re 95% +++, rp 90% +++, her2 2+, ki67 50%
# extensión del tumor: ptic, pn0(sn) mx ec ia
# biología tumoral: g3, re 95% +++, rp 90% +++, her2 2+, ki67 50%
# biología tumoral: g3, re 95% +++, rp 90% +++, her2 2+, ki67 50% e mb rise rte ha m e uu ie aaa y ur apn els y a+ er l ty. < ” na» "r
# extensión del tumor: pt1c, pn0(sn) mx ec ia aparece en el video 20
# Se detectó mama: mama_izquierda
# _________________________
# mlgm / 283718 / 81 años / dr. soto
# diagnóstico: cáncer de mama derecha ec ia rh +, her2 negativo.
# comorbilidades: cáncer de mama derecha (1997) cuadrantectomía de mama derecha + radioterapia + tamoxifeno durante 5 años. temblor esencial / trastorno depresivo mayor / trastorno de ansiedad generalizada / síndrome de intestino irritable con predominio de diarrea / dislipidemia / osteoartritis / osteoporosis / prediabetes. medicamentos: rivotril gotas por la noche, duloxetina 60 mg vo cada 24 horas, lorazepam 0.5 mg vo cada 24 horas, mirtazapina 30 mg vo cada 24 horas, propranolol 20 mg vo cada 8 horas, loperamida 2 mg cada 24 horas, atorvastatina 40 mg vo cada 24 horas, clonazepam 4 gotas vo cada 24 horas, olcalciferol / vitamina d, histofil 4000 ul cada tercer dia
# ahf oncológicos: madre cáncer de mama a los dq años.
# tabaco: negado
# alcohol: negado
# drogas: negado
# fum: a los 50 años
# aco negado
# trho: negado
# 25.07.23: biopsia de nódulo de sospecha: rhp (q-23-5192): carcinoma papilar invasor; grado 1 (2+2+1); cdis -, ilv -, ipn -; microcalcificaciones - ; ihq: re 3+ (80%), rp 3+ (80%), her-2 1+ (negativo), ki-67 10% d
# extensión del tumor: ct1c (19 mm) cn0 mx
# biología tumoral: re 80%, rp 80% her2 1+ ki67 10%
# estado hormonal: postmenopáusica
# Se detectó mama: mama_derecha
# _________________________
# cje / 312199 / 50 años / dra. martínez
# diagnóstico: cdi mama derecha, multifocal, ec iia (ct1c, c(f)n1, m0) luminal b her 2 negativo
# tabaco: negado
# alcohol: ocasional
# drogas: negado
# ahf oncológicos: prima hermana de rama materna con cáncer de mama a los 48 años.
# fum 2016 quirúrgica (histerectomía 2016)
# g5 p2 c2 a1
# aco 6 años (23-29 años).
# estado hormonal: premenopáusica.
# comorbilidades: 1 negado
# 04.2022 lesión palpable en axila derecha. abordaje en fucam incmnsz
# 22: mg
# usg: birads 6
# 06.10.22 pet/ct 18.-fdg: no se identifican adenopatías cervicales. lesión irregular sólida de bordes mal delimitados en cuadrantes superiores de la mama derecha, se asocia a incremento del metabolismo con suv máximo de 2.6. adenopatías axilares y retropectorales derechas con eje corto de hasta 20 mm asociados a hiper metabolismo con suv máximo de 6.3. no se identifican datos de enfermedad a distancia. q22-5713 revisión de laminillas: cdi spe, con áreas mucinosas del 10%, g2, cdis (-), ilv(+), ipn(-), microcalcificaciones (-), re 90%, rp 70%, her2 0+ negativo, ki67 30%. ganglio linfático con metástasis de cdi mucinoso.
# 06.10.22 estradiol 137, fsh 5.94
# 11.10.22 ufcm: t1c, cn1, se podría plantear tratamiento neoadyuvante
# 31.10.2022 - 02.01.23 paclitaxel semanal s3 - s12
# 16.01.23 — 27.02.23 acdd x 4 23 smd: cuadrantectomía en sitio de primario de mama + dirección axilar, la lesión retropectoral se como resecable.
# 10.04.23 cuadrantectomía superior externa derecha + disección axilar.
# cdi de tipo mixto con componente mucinoso (30 %) grado 2 (3+2+1), tamaño del tumor: 1.8 cm (medido en laminilla), focalidad del tumor: no se puede determinar.
# carcinoma ductal in situ: presente, patrón arquitectural cribiforme y solido, grado nuclear: 2 (intermedio), necrosis: ausente, microcalcificaciones: presente. ipn e ilv: ausente. microcalcificaciones: presentes, márgenes: todos negativos a células neoplásicas. ganglios linfáticos: 8 ganglio linfáticos evaluados en total, 2 ganglios positivos a células neoplásicas, depósito de mayor, tamaño: 1.7 cm sin ruptura capsular ypt1cn1a, hallazgos adicionales: adenosis esclerosante. re 80%, rp 70%, her2 1+, ki 67 10%
# 27.04.23: estradiol 8.99, fsh 75 n0 hay dgt cicatriz quirúrgica de mama derecha sin alteraciones, no se palpan lesiones sospechosas.
# biología tumoral: re 90%, rp 70%, her2 0+ negativo, ki67 30%
# biología tumoral post tratamiento: re 80%, rp 0%, her2 1+, ki67 10%. 2) plan: rt adyuvante + hormonoterapia (tamoxifeno + ofs)
# estado hormonal: premenopáusica
# Se detectó mama: mama_derecha
# _________________________
# amdg / 313738 / 46 años / dra. verduzco
# diagnóstico: cdi de mama izquierda triple negativo ec iiib (ct4bn1mo)
# comorbilidades: 1. enfermedad inflamatoria crónica por modelantes (2000) 2. melanoma de extensión superficial ec ia (09.2021) - 09.2021 biopsia excisional - rhp externo: melanoma de extensión superficial, clark 11, breslow 0.75 mm, sin mitosis, ilv (-), ipn (-). - 2021 cirugía de ampliación de margenes y ganglio centinela, no contamos con el reporte. 3. o ansiedad generalizada (2023) e q
# ahf oncológicos: negados
# tabaco: negado
# alcohol: ocasional
# menarca 12 años / fum 27.02.23
# g2 p0 c2 a0 - paridad satisfecha
# anticoncepción hormonal: parches etinilestradiol 5 a
# estado hormonal: premenopáusica
# 23.11.22 autopalf
# 24.11.22 mmg nó morfología y aumi
# 06.12.22 biopsia | ki67 30% fis
# 13.01.23 pet-ct imágenes nodulal relación a granulc
# 24.02.23 rmn cré intra y extra-axiale
# 15.03.23 colocac
# 24.03.23 c1 doxc incmnsz revisión de lamin
# 27.03.23 mmg/u* las 2 de 3. 2 cm, «
# 29.03.23 pet fdc metabolismo
# 04.04.23 ufcm: f q/o00mmo € ación de tumoración en mama y axila izquierda julo en mama, irregular, no especifica tamaño. región axilar izquierda: ganglios con pérdida de la nto de tamaño. biradss5. or trucut (rhp externo): carcinoma ductal infiltrante, g3, ipn +, ilv +. ihq: re 0%, rp 0%, her2 1: no amplificado (inmuno0q)) dg: tumoración hipermetabólica en mama izquierda, adenopatías axilares izquierdas. múltiples os en tejido subcutáneo de la región glútea asociados a incremento difuso del metabolismo en nas. neo simple y con contraste: cambios por microangiopatía fasekas 1, sin evidencia de lesiones s, por sintomatología inespecífica n de catéter puerto pectoral derecho rubicina + ciclofostfomida las (q-23-2011): cdi g2 (3+2+2), ilv+, ipn-, re 0%, rp 0%, her2 1+, ki67 40%. en mama derecha no hay imágenes sólidas. en mama izquierda nódulos hipoecoicos en el eje de n el eje de las 4 de 1. 12 cm. ganglios con pérdida de morfología en axila izquierda. seat; nódulo en cse de mama izquierda + adenopatías axilares con incremento del or parte de oncología médica se decide ofrecer neoadyuvancia con io+qt. j
# 11.04.23 ecott fracción de eyección de 63%, strain de -21.3%.
# 17.04.23 - 29.05.23: c2-c4 doxorrubicina/ciclofostamida + c1-3 pembrolizumab
# 24.05.23: colocación de clip mamario
# 20.06.23 s1 paclitaxel/carboplatino + c4 pembrolizumab > insuficiencia adrenal inmunomediada g2
# 28.06.23-09.08.23 s2-s7 paclitaxel/carboplatino
# 11.08.23 mmg/us nódulo en mama izquierda en topografía de primario conocido que mide 1.0 cm, así como disminución en dimensiones de adenopatías axilares en relación con respuesta parcial.
# 16.08.23-06.09.23 s8-s11 paclitaxel/carboplatino
# 19.09.23 mmg/us se compara con estudio previo, en cse tercio posterior de mama izquierda nódulo redondo con reforzamiento heterogéneo con marcador de biopsia, en axila un ganglio con engrosamiento cortical y reforzamiento heterogéneo. al ultrasonido en axila ganglios con engrosamiento cortical, en el eje de las 3 nódulo irregular de 1cm. o/luumgdo q ñ mama izquierda sin lesiones palpables, sin adenopatías axilares má palpables
# extensión del tumor: cdi de mama izquierda ec iiib ct4 — 3.2 cm + nódulo satélite cn1
# biología tumoral: triple negativo re 0%, rp 0%, her2 1+, ki67 30%
# estado hormonal: premenopáusica
# Se detectó mama: mama_izquierda
# _________________________
# tcg / 312787 / 54 años / dra. martínez
# diagnóstico: cdi de mama deregha ec iia re+, her2+
# comorbilidades: 1. diabetes tipo 2 (2014) 2. herpes zóster en región lumbar (2022)
# tabaco: negado
# alcohol: negado
# drogas: negado
# ahf oncológicos: negados
# menarca 14 años / fum 2015 (46 años)
# g2 p2 c0 a0 - mpf- progestágenos im por 6 años - estado hormonal: postmenopáusica
# 04.2022 palpación de tumor en mama derecha
# 08.11.22 mastografía/usg nódulo espiculado de 8 cm y asimetría focal con distorsión arquitectura con hallazgos que sugieren infiltración a piel y ganglios axilares ipsilaterales multifocales y multicéntrico en mama derecha requieren biopsia. categoría birads 5.
# 09.11.22 biopsia mama derecha (q22-6611) cdi nos, g1 (2+1y1) con carcinoma ductal in situ presente, ilv-. ihq re 95% rp 0% her2 +++, ki67 10%
# 09.11.22 baaf ganglio axilar derecho. b-a22-280. carcinoma moderadamente diferenciado.
# 14.12.22 pet-ct (18-fdg): lesiones en mama derecha hipermetabólicas compatibles con actividad neoplásica primaria conocida, a considerar enfermedad multicéntrica. adenopatías axilares derechas asociadas a metabolismo en relación con depósito secundario. no se identifican datos de enfermedad a distancia.
# 22.12.22 ecott: fevi 64%, strain -20.8%
# 29.12.22-13.04.23 c1-c6 tchp
# 19.04.23 usg patrón mamario de tipo b. datos de respuesta parcial de acuerdo a los criterios de resist 1.1. hallazgos benignos correspondientes de la categoría. ganglios axilares de morfología conservada. birads 6. o/rl.enqo no se palpa lesión en mama derecha, axila ipsilateral sin adenopatías. mama y axila izquierda sin lesiones palpables. no se palpan adenopatías infra/ supraclaviculares o cervicales. o/rleando > n0 hay dgt
# extensión del tumor: cdi de mama derecha ec iia ct3 - 8 cm c(f)n1
# biología tumoral: luminal b, her2+ re 95% rp 0% her2 +++, ki67 10%
# estado hormonal: postmenopáusica
# Se detectó mama: mama
# ahf: madre cáncer de colón a los 62 años. tío paterno con antecedente de cáncer de piel finado a los 25 años. histerectomía +lsal o a l años por tumor ovárico qeda biopsia abierta de mama (2011) god benigno, microcalcificaciones) apendicectomía abierta en el 2018 curso con tonitis. e sección amplia de carcinoma basocelular en cuero cabelludo el 25.07.22 cirugía de catarata bilateral 03.2022 - g0
# menarca 15 años. terapia de reemplazo hormonal con estrógenos conjugados por 3 años, después estradiol en gel, parches hasta el 2023.
# diagnóstico: carcinoma mucinoso ec ha (ct2, cno0, m0)
# ahf: madre cáncer de colón a los 62 años. tío paterno con antecedente de cáncer de piel finado a los 25 años.
# e menarca 15 años.
# dismorfía (talla baja, pies y manos pequeñas, alteraciones faciales y retraso psicomotor)
# enfermedad celíaca (2005)
# estado hormonal: postmenopáusica
# extensión del tumor: biología tumoral: ct2, cn0, m0 re 90%, rp 20%, hér2 1+, ki67 5%.
# estado hormonal: postmenopáusica
# extensión del tumor: ct2, cn0, m0
# estado hormonal: postmenopáusica
# extensión del tumot: ct2, cn0, m0
# estado hormonal: postmenopáusica
# Se detectó mama: None
# _________________________
# lne / 207897 / 43 años / dra. martínez
# diagnóstico: cdi de mama izquierda ec iia (ct2,cn0,m0) triple negativo
# ahf oncológicos: negados
# fum 2022.g 1,p 1.
# aco negados.
# comorbilidades: lnh asociado a conjuntiva - ec ia (2002). 08.05.03 último tx cop x6 = rc chop x6 (sin rtx x ). bx 25/05/05: sin infiltración = 2a rc. vigilancia anual.
# 23.09.22 mmg/usg: nódulo en interlínea de cuadrantes superiores de mama izquierda (r11-12lc) de 2.4 cm. ganglios axilares de características normales. rhp: cdi de mama spe g2, re -, rp -, her 2 1+, k167 50%.
# 13.12.22 pet ct: lesión con hipermetabolismo en mama izquierda. no se observan otros sitios de metabolismo anormal.
# 16.12.22 se considera candidata a qt+i0 neoadyuvante. estimamos que ha recibido al menos una dosis acumulada de 300 mg/m2 de doxorrubicina.
# 26.12.22 - 01.03.23 s1-s12 cbp/taxol + pembrolizumab - respuesta clínica completa
# 22.03.23 mmg mama izquierda: se colocó marcador.
# 28.03.23 ufcm: se propone doxorrubicina liposomal 35 mg/m2 y ciclofosfamida 600 mg/m2 + 1o dosis fija.
# 01.04.23-14.05.23 c1-3 ac (doxorrubicina liposomal 35 mg/m2) + pembrolizumab.
# 07.06.23 hdd: edpp g3, mayor edema en ambos pies a comparación de 1 semana previa. se observan lesiones ulcerosas en pies de forma bilateral sin datos francos de infección activa. suspendemos qt.
# 23.06.23 no concluyó los 4 ciclos de ac + pembrolizumab por toxicidad (edpp g3
# 23.06.23 mmg /usg: disminución de lesión en interlínea de cuadrantes interiores, respuesta del 35%
# 13.07.23: p0 cc + gc rhp: q-23-4804 carcinoma papilar invasor g2, 2x1.1 cm ilv (-), mq (-), gl 0/3 re (-), rp (-), her2 -), ki67 60% p63(-), cks/6 (-) ck34be12 positivo 10%
# extensión del tumor: ypt2, pno0 (sn), m0 ec iia
# biología tumoral: aparece en el video 18
# Se detectó mama: mama_izquierda
# Intentando llenar inmunohistoquímica tumoral con su mapa
# _________________________
